# %% [markdown]
# # Notebook 01: Exploratory Data Analysis and Reporting
#
# This notebook performs a detailed analysis of the cleaned Home Credit dataset, including per-variable summaries, target-stratified analyses, default rate per category, and correlation visualization. Methodology aligns with best practices as described in Harrell (2015) and is modeled after Berg et al. (2020).

# %% [markdown]
# **Key EDA References:**
#
# - Harrell, F. E. (2015). Regression Modeling Strategies. Springer. (See Chapters 3 and 4 for recommended variable-by-variable reporting and stratification by outcome.)
# - Berg, T., Burg, V., Gombović, A., & Puri, M. (2020). On the Rise of FinTechs: Credit Scoring Using Digital Footprints. Review of Financial Studies, 33(7), 2845–2897. (See their Table 2 and reporting methodology.)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Load the cleaned, subsampled dataset
df = pd.read_csv('/home/frederickerleigh/Dokumente/Fintech Seminar/NewCode/FintechSeminar-Synthetic-Dataset/fintech-credit-scoring-seminar/data/processed/home_credit_sample.csv')

# %% [markdown]
# ## General summary statistics
#
# Overview for numeric and categorical variables.

# %%
summary = df.describe(include='all').T
summary['missing_pct'] = df.isnull().mean()
display(summary)
summary.to_csv('/home/frederickerleigh/Dokumente/Fintech Seminar/NewCode/FintechSeminar-Synthetic-Dataset/fintech-credit-scoring-seminar/results/tables/reporting_overview_summary.csv')
# Out:
#                               count unique                            top  \
# EXT_SOURCE_1                 5000.0    NaN                            NaN
# EXT_SOURCE_2                 5000.0    NaN                            NaN
# EXT_SOURCE_3                 5000.0    NaN                            NaN
# AMT_CREDIT                   5000.0    NaN                            NaN
# AMT_ANNUITY                  5000.0    NaN                            NaN
# AMT_GOODS_PRICE              5000.0    NaN                            NaN
# DAYS_BIRTH                   5000.0    NaN                            NaN
# CODE_GENDER                    5000      2                              F
# CNT_CHILDREN                 5000.0    NaN                            NaN
# CNT_FAM_MEMBERS              5000.0    NaN                            NaN
# NAME_EDUCATION_TYPE            5000      5  Secondary / secondary special
# NAME_FAMILY_STATUS             5000      5                        Married
# NAME_HOUSING_TYPE              5000      6              House / apartment
# NAME_INCOME_TYPE               5000      5                        Working
# AMT_INCOME_TOTAL             5000.0    NaN                            NaN
# REGION_POPULATION_RELATIVE   5000.0    NaN                            NaN
# REGION_RATING_CLIENT         5000.0    NaN                            NaN
# REGION_RATING_CLIENT_W_CITY  5000.0    NaN                            NaN
# DAYS_EMPLOYED                5000.0    NaN                            NaN
# DAYS_REGISTRATION            5000.0    NaN                            NaN
# DAYS_ID_PUBLISH              5000.0    NaN                            NaN
# FLAG_MOBIL                   5000.0    NaN                            NaN
# FLAG_EMP_PHONE               5000.0    NaN                            NaN
# FLAG_WORK_PHONE              5000.0    NaN                            NaN
# FLAG_EMAIL                   5000.0    NaN                            NaN
# WEEKDAY_APPR_PROCESS_START     5000      7                      WEDNESDAY
# HOUR_APPR_PROCESS_START      5000.0    NaN                            NaN
# REG_REGION_NOT_LIVE_REGION   5000.0    NaN                            NaN
# REG_REGION_NOT_WORK_REGION   5000.0    NaN                            NaN
# LIVE_REGION_NOT_WORK_REGION  5000.0    NaN                            NaN
# REG_CITY_NOT_LIVE_CITY       5000.0    NaN                            NaN
# REG_CITY_NOT_WORK_CITY       5000.0    NaN                            NaN
# LIVE_CITY_NOT_WORK_CITY      5000.0    NaN                            NaN
# TARGET                       5000.0    NaN                            NaN
#
#                              freq         mean            std       min  \
# EXT_SOURCE_1                  NaN     0.503611       0.139889  0.039579
# EXT_SOURCE_2                  NaN     0.511512       0.190548  0.000085
# EXT_SOURCE_3                  NaN     0.514711        0.17291  0.000527
# AMT_CREDIT                    NaN   604635.183  406377.614999   45000.0
# AMT_ANNUITY                   NaN   27331.3899   14623.093876    3145.5
# AMT_GOODS_PRICE               NaN  543855.5865  371623.026268   45000.0
# DAYS_BIRTH                    NaN  -15952.7762    4409.809171  -25142.0
# CODE_GENDER                  3338          NaN            NaN       NaN
# CNT_CHILDREN                  NaN        0.428       0.734387       0.0
# CNT_FAM_MEMBERS               NaN       2.1668       0.917794       1.0
# NAME_EDUCATION_TYPE          3568          NaN            NaN       NaN
# NAME_FAMILY_STATUS           3188          NaN            NaN       NaN
# NAME_HOUSING_TYPE            4415          NaN            NaN       NaN
# NAME_INCOME_TYPE             2584          NaN            NaN       NaN
# AMT_INCOME_TOTAL              NaN  166728.1707   94049.836763   27000.0
# REGION_POPULATION_RELATIVE    NaN     0.020653       0.013736  0.000533
# REGION_RATING_CLIENT          NaN        2.067         0.5128       1.0
# REGION_RATING_CLIENT_W_CITY   NaN       2.0444       0.505648       1.0
# DAYS_EMPLOYED                 NaN   64564.1074  141857.066237  -15202.0
# DAYS_REGISTRATION             NaN   -5054.7856    3518.539432  -19463.0
# DAYS_ID_PUBLISH               NaN    -2968.805    1501.227647   -6194.0
# FLAG_MOBIL                    NaN          1.0            0.0       1.0
# FLAG_EMP_PHONE                NaN        0.818       0.385883       0.0
# FLAG_WORK_PHONE               NaN        0.205       0.403742       0.0
# FLAG_EMAIL                    NaN       0.0562       0.230331       0.0
# WEEKDAY_APPR_PROCESS_START    873          NaN            NaN       NaN
# HOUR_APPR_PROCESS_START       NaN       12.023       3.250259       1.0
# REG_REGION_NOT_LIVE_REGION    NaN       0.0162       0.126257       0.0
# REG_REGION_NOT_WORK_REGION    NaN       0.0526       0.223256       0.0
# LIVE_REGION_NOT_WORK_REGION   NaN       0.0432       0.203327       0.0
# REG_CITY_NOT_LIVE_CITY        NaN       0.0818       0.274087       0.0
# REG_CITY_NOT_WORK_CITY        NaN       0.2348       0.423916       0.0
# LIVE_CITY_NOT_WORK_CITY       NaN       0.1832       0.386869       0.0
# TARGET                        NaN       0.0808       0.272555       0.0
#
#                                   25%       50%        75%        max  \
# EXT_SOURCE_1                 0.505998  0.505998   0.505998   0.931751
# EXT_SOURCE_2                 0.387881   0.56425    0.66138   0.809908
# EXT_SOURCE_3                 0.411849  0.535276   0.633032   0.885488
# AMT_CREDIT                   270000.0  518562.0   810000.0  2700000.0
# AMT_ANNUITY                   16573.5  25328.25  34756.875   130018.5
# AMT_GOODS_PRICE              238500.0  450000.0   679500.0  2700000.0
# DAYS_BIRTH                   -19683.0  -15715.0   -12141.0    -7680.0
# CODE_GENDER                       NaN       NaN        NaN        NaN
# CNT_CHILDREN                      0.0       0.0        1.0        5.0
# CNT_FAM_MEMBERS                   2.0       2.0        3.0        6.0
# NAME_EDUCATION_TYPE               NaN       NaN        NaN        NaN
# NAME_FAMILY_STATUS                NaN       NaN        NaN        NaN
# NAME_HOUSING_TYPE                 NaN       NaN        NaN        NaN
# NAME_INCOME_TYPE                  NaN       NaN        NaN        NaN
# AMT_INCOME_TOTAL             112500.0  144000.0   202500.0  1350000.0
# REGION_POPULATION_RELATIVE   0.010006   0.01885   0.028663   0.072508
# REGION_RATING_CLIENT              2.0       2.0        2.0        3.0
# REGION_RATING_CLIENT_W_CITY       2.0       2.0        2.0        3.0
# DAYS_EMPLOYED                -2685.25   -1196.5    -301.75   365243.0
# DAYS_REGISTRATION            -7616.25   -4581.0    -2106.0        0.0
# DAYS_ID_PUBLISH               -4284.0   -3226.0    -1682.5        0.0
# FLAG_MOBIL                        1.0       1.0        1.0        1.0
# FLAG_EMP_PHONE                    1.0       1.0        1.0        1.0
# FLAG_WORK_PHONE                   0.0       0.0        0.0        1.0
# FLAG_EMAIL                        0.0       0.0        0.0        1.0
# WEEKDAY_APPR_PROCESS_START        NaN       NaN        NaN        NaN
# HOUR_APPR_PROCESS_START          10.0      12.0       14.0       22.0
# REG_REGION_NOT_LIVE_REGION        0.0       0.0        0.0        1.0
# REG_REGION_NOT_WORK_REGION        0.0       0.0        0.0        1.0
# LIVE_REGION_NOT_WORK_REGION       0.0       0.0        0.0        1.0
# REG_CITY_NOT_LIVE_CITY            0.0       0.0        0.0        1.0
# REG_CITY_NOT_WORK_CITY            0.0       0.0        0.0        1.0
# LIVE_CITY_NOT_WORK_CITY           0.0       0.0        0.0        1.0
# TARGET                            0.0       0.0        0.0        1.0
#
#                              missing_pct
# EXT_SOURCE_1                         0.0
# EXT_SOURCE_2                         0.0
# EXT_SOURCE_3                         0.0
# AMT_CREDIT                           0.0
# AMT_ANNUITY                          0.0
# AMT_GOODS_PRICE                      0.0
# DAYS_BIRTH                           0.0
# CODE_GENDER                          0.0
# CNT_CHILDREN                         0.0
# CNT_FAM_MEMBERS                      0.0
# NAME_EDUCATION_TYPE                  0.0
# NAME_FAMILY_STATUS                   0.0
# NAME_HOUSING_TYPE                    0.0
# NAME_INCOME_TYPE                     0.0
# AMT_INCOME_TOTAL                     0.0
# REGION_POPULATION_RELATIVE           0.0
# REGION_RATING_CLIENT                 0.0
# REGION_RATING_CLIENT_W_CITY          0.0
# DAYS_EMPLOYED                        0.0
# DAYS_REGISTRATION                    0.0
# DAYS_ID_PUBLISH                      0.0
# FLAG_MOBIL                           0.0
# FLAG_EMP_PHONE                       0.0
# FLAG_WORK_PHONE                      0.0
# FLAG_EMAIL                           0.0
# WEEKDAY_APPR_PROCESS_START           0.0
# HOUR_APPR_PROCESS_START              0.0
# REG_REGION_NOT_LIVE_REGION           0.0
# REG_REGION_NOT_WORK_REGION           0.0
# LIVE_REGION_NOT_WORK_REGION          0.0
# REG_CITY_NOT_LIVE_CITY               0.0
# REG_CITY_NOT_WORK_CITY               0.0
# LIVE_CITY_NOT_WORK_CITY              0.0
# TARGET                               0.0

# %% [markdown]
# ## Numeric variable distributions (overall)

# %%
numeric_vars = df.select_dtypes(include=[np.number]).columns.drop('TARGET')
for col in numeric_vars:
    plt.figure(figsize=(6,3))
    sns.histplot(df[col], bins=30, kde=True)
    plt.title(f'Distribution: {col}')
    plt.savefig(f'/home/frederickerleigh/Dokumente/Fintech Seminar/NewCode/FintechSeminar-Synthetic-Dataset/fintech-credit-scoring-seminar/results/figures/{col}_hist.png')
    plt.close()

# %% [markdown]
# ## Default rate by category for each categorical variable
#
# For every categorical variable (e.g., education, gender), show each value, count, and the default rate (`TARGET=1`).

# %%
import os
os.makedirs('/home/frederickerleigh/Dokumente/Fintech Seminar/NewCode/FintechSeminar-Synthetic-Dataset/fintech-credit-scoring-seminar/results/tables/default_rate_per_variable', exist_ok=True)

cat_vars = df.select_dtypes(include=['object', 'category']).columns

# Save one CSV per categorical variable
for col in cat_vars:
    table = df.groupby(col)['TARGET'].agg(['count', 'mean']).reset_index()
    table.rename(columns={'mean': 'default_rate'}, inplace=True)
    table['default_rate'] = table['default_rate'].round(4)
    table.to_csv(f'/home/frederickerleigh/Dokumente/Fintech Seminar/NewCode/FintechSeminar-Synthetic-Dataset/fintech-credit-scoring-seminar/results/tables/default_rate_per_variable/{col}_default_rate.csv', index=False)

# %% [markdown]
# ## Single summary table: all categorical variable default rates
#
# Combine all (variable, value, default rate) info into one big CSV for review.

# %%
cat_default_list = []
for col in cat_vars:
    table = df.groupby(col)['TARGET'].agg(['count', 'mean']).reset_index()
    table['variable'] = col
    table.rename(columns={col: 'value', 'mean': 'default_rate'}, inplace=True)
    table['default_rate'] = table['default_rate'].round(4)
    cat_default_list.append(table[['variable', 'value', 'count', 'default_rate']])
cat_default_summary = pd.concat(cat_default_list, ignore_index=True)
cat_default_summary.to_csv('/home/frederickerleigh/Dokumente/Fintech Seminar/NewCode/FintechSeminar-Synthetic-Dataset/fintech-credit-scoring-seminar/results/tables/default_rate_per_variable/categorical_default_summary.csv', index=False)
cat_default_summary.head()
# Out:
#               variable              value  count  default_rate
# 0          CODE_GENDER                  F   3338        0.0725
# 1          CODE_GENDER                  M   1662        0.0975
# 2  NAME_EDUCATION_TYPE    Academic degree      1        0.0000
# 3  NAME_EDUCATION_TYPE   Higher education   1176        0.0493
# 4  NAME_EDUCATION_TYPE  Incomplete higher    190        0.0737

# %% [markdown]
# ## Default rate by value bin for numeric variables
#
# Bin each numeric variable (quartiles), show default rate per bin.

# %%
import numpy as np

numeric_vars = df.select_dtypes(include=[np.number]).columns.drop('TARGET')
numeric_default_list = []
for col in numeric_vars:
    try:
        # Use 4 quantile bins (quartiles)
        df[f'{col}_bin'] = pd.qcut(df[col], q=4, duplicates='drop')
        table = df.groupby(f'{col}_bin')['TARGET'].agg(['count', 'mean']).reset_index()
        table['variable'] = col
        table.rename(columns={'mean': 'default_rate', f'{col}_bin': 'bin'}, inplace=True)
        table['default_rate'] = table['default_rate'].round(4)
        numeric_default_list.append(table[['variable', 'bin', 'count', 'default_rate']])
        # Save per-variable as well
        table.to_csv(f'/home/frederickerleigh/Dokumente/Fintech Seminar/NewCode/FintechSeminar-Synthetic-Dataset/fintech-credit-scoring-seminar/results/tables/default_rate_per_variable/{col}_binned_default_rate.csv', index=False)
    except Exception as e:
        print(f"Could not bin {col}: {e}")

# All in one file
if numeric_default_list:
    numeric_default_summary = pd.concat(numeric_default_list, ignore_index=True)
    numeric_default_summary.to_csv('/home/frederickerleigh/Dokumente/Fintech Seminar/NewCode/FintechSeminar-Synthetic-Dataset/fintech-credit-scoring-seminar/results/tables/default_rate_per_variable/numeric_binned_default_summary.csv', index=False)
    numeric_default_summary.head()
